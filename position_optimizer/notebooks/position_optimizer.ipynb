# %%
import os
import json
import numpy as np
import pickle 
import tqdm
from scipy import sparse
from collections import defaultdict
from pprint import pprint
from collections import Counter
from itertools import permutations

# %% [markdown]
# # Decoder
#
# Read steam api match and create match datapoint
#
# ```
# for each team; predict_log_proba for each hero in team
#
# append log_proba to
#
#         pos
#
# h1  p   p   p   p   p
# h2  p   p   p   p   p
# h3  p   p   p   p   p
# h4  p   p   p   p   p
# h5  p   p   p   p   p
# ```
#
# Create permutations for team (0 to 4, r=5). Use itertools permutations
# ```
# c = [1,3,0,4,2] // get the log_prob by index in pos matrix
# log_p = sum(c)
# if log_p > best_p:
#     best_p = log_p
#     best_c = c
#
# ```

# %%
with open("../data/steam_api_match_example.json", "r") as f:
    match = json.load(f)
    match = match["result"]

with open("../data/clfs/logreg_clfs_all.pkl", "rb") as f:
    clfs = pickle.load(f)

with open("../data/heroes.json", "r") as f:
    heroes = json.load(f)
    heroes_id_to_name = {hero["id"]: hero["localized_name"] for hero in heroes}

def is_valid_match(match):
    if "match_id" not in match:
        return False
    if not match["lobby_type"] in {0, 5, 6, 7}:
        print("Invalid lobby type:", match["lobby_type"])
        return False
    if match["duration"] < 60 * 20:
        print("Invalid duration:", match["duration"])
        return False
    if not match["game_mode"] in {1, 2, 16, 22}:
        print("Invalid game mode:", match["game_mode"])
        return False

    return True

def get_rank(rank: int):
    oh = np.zeros(5)
    oh[rank] = 1
    return oh

opendota_data_path = "../data/dataset_positions_all.pkl" 
with open(opendota_data_path, 'rb') as fp:
    data = pickle.load(fp)

def remove_unplayed_roles(hid, y_pred, threshold=200):
    ys = data["ys"]
    role_counts = dict(Counter(ys[hid]))
    updated_y_pred = np.zeros(y_pred.shape)

    for k in range(0,5):
        if role_counts[k + 1] < threshold:
            updated_y_pred[k] = -1000.
        else:
            updated_y_pred[k] = y_pred[k]
    return updated_y_pred


def find_optimal_roles(match):
    players = match["players"]
    t0 = [p for p in players if p["player_slot"] < 128]
    t1 = [p for p in players if p["player_slot"] >= 128]

    for team in [t0, t1]:
        # !Ranks
        attributes = ["gold_per_min", "xp_per_min", "kills", "deaths", "assists", "last_hits", "hero_damage", "tower_damage"]
        ranks = {attr: sorted([(p["hero_id"], p[attr]) for p in team], key=lambda x: x[1], reverse=True) for attr in attributes}
        hids = [p["hero_id"] for p in team]
        team_position_proba = defaultdict(list)
        
        # !Create c
        for p in team:
            features = []
            hid = p["hero_id"]

            teammates = np.zeros((136))
            for team_hid in hids:
                if team_hid != hid:
                    teammates[team_hid] = 1.
            
            features.append(teammates)
            
            for rank in ranks: 
                features.append(get_rank(ranks[rank].index((hid, p[rank]))))

            x = np.concatenate(features)
            y_pred = clfs[hid].predict_log_proba(x.reshape(1, -1))
            updated_y_pred = remove_unplayed_roles(hid, y_pred.ravel())         
            team_position_proba[hid] = updated_y_pred

        best_log_p = -np.inf
        best_comp = None

        # Optimal 
        for comp in permutations(range(5), 5):
            comp_with_heroid = [(comp[i], heroes_id_to_name[hid], round(team_position_proba[hid][comp[i]], 2)) for i, hid in enumerate(hids)]
            print(comp_with_heroid)
            log_p = np.array([team_position_proba[hid][comp[i]] for i, hid in enumerate(hids)]).sum()
            if log_p > best_log_p:
                best_log_p = log_p
                best_comp = sorted(comp_with_heroid, key=lambda x: x[0])
    


        # Greedy            

        # break
            # arg_max = np.argmax(team_position_proba[hid])
            
        # argmax team_position_proba
        # sett alt annet en pos til -inf



        # print("{} => {:.2f}".format(best_comp, best_log_p))

    return best_comp


if is_valid_match(match):
    comp = find_optimal_roles(match)
    print(comp)
# Out:
# /home/bao/anaconda3/envs/dota/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# [(0, 'Windranger', -1000.0), (1, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (3, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(0, 'Windranger', -1000.0), (1, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (4, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(0, 'Windranger', -1000.0), (1, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (2, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(0, 'Windranger', -1000.0), (1, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (4, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(0, 'Windranger', -1000.0), (1, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (2, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(0, 'Windranger', -1000.0), (1, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (3, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(0, 'Windranger', -1000.0), (2, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (3, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(0, 'Windranger', -1000.0), (2, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (4, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(0, 'Windranger', -1000.0), (2, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (1, 'Clinkz', -3.36), (4, 'Zeus', -2.44)]
# [(0, 'Windranger', -1000.0), (2, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (4, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(0, 'Windranger', -1000.0), (2, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (1, 'Clinkz', -3.36), (3, 'Zeus', -0.88)]
# [(0, 'Windranger', -1000.0), (2, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (3, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(0, 'Windranger', -1000.0), (3, 'Grimstroke', -2.22), (1, 'Pudge', -1.83), (2, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(0, 'Windranger', -1000.0), (3, 'Grimstroke', -2.22), (1, 'Pudge', -1.83), (4, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(0, 'Windranger', -1000.0), (3, 'Grimstroke', -2.22), (2, 'Pudge', -0.39), (1, 'Clinkz', -3.36), (4, 'Zeus', -2.44)]
# [(0, 'Windranger', -1000.0), (3, 'Grimstroke', -2.22), (2, 'Pudge', -0.39), (4, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(0, 'Windranger', -1000.0), (3, 'Grimstroke', -2.22), (4, 'Pudge', -3.76), (1, 'Clinkz', -3.36), (2, 'Zeus', -3.51)]
# [(0, 'Windranger', -1000.0), (3, 'Grimstroke', -2.22), (4, 'Pudge', -3.76), (2, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(0, 'Windranger', -1000.0), (4, 'Grimstroke', -0.12), (1, 'Pudge', -1.83), (2, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(0, 'Windranger', -1000.0), (4, 'Grimstroke', -0.12), (1, 'Pudge', -1.83), (3, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(0, 'Windranger', -1000.0), (4, 'Grimstroke', -0.12), (2, 'Pudge', -0.39), (1, 'Clinkz', -3.36), (3, 'Zeus', -0.88)]
# [(0, 'Windranger', -1000.0), (4, 'Grimstroke', -0.12), (2, 'Pudge', -0.39), (3, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(0, 'Windranger', -1000.0), (4, 'Grimstroke', -0.12), (3, 'Pudge', -2.38), (1, 'Clinkz', -3.36), (2, 'Zeus', -3.51)]
# [(0, 'Windranger', -1000.0), (4, 'Grimstroke', -0.12), (3, 'Pudge', -2.38), (2, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(1, 'Windranger', -0.9), (0, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (3, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(1, 'Windranger', -0.9), (0, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (4, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(1, 'Windranger', -0.9), (0, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (2, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(1, 'Windranger', -0.9), (0, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (4, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(1, 'Windranger', -0.9), (0, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (2, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(1, 'Windranger', -0.9), (0, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (3, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(1, 'Windranger', -0.9), (2, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (3, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(1, 'Windranger', -0.9), (2, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (4, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(1, 'Windranger', -0.9), (2, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (0, 'Clinkz', -0.04), (4, 'Zeus', -2.44)]
# [(1, 'Windranger', -0.9), (2, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (4, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(1, 'Windranger', -0.9), (2, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (0, 'Clinkz', -0.04), (3, 'Zeus', -0.88)]
# [(1, 'Windranger', -0.9), (2, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (3, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(1, 'Windranger', -0.9), (3, 'Grimstroke', -2.22), (0, 'Pudge', -3.05), (2, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(1, 'Windranger', -0.9), (3, 'Grimstroke', -2.22), (0, 'Pudge', -3.05), (4, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(1, 'Windranger', -0.9), (3, 'Grimstroke', -2.22), (2, 'Pudge', -0.39), (0, 'Clinkz', -0.04), (4, 'Zeus', -2.44)]
# [(1, 'Windranger', -0.9), (3, 'Grimstroke', -2.22), (2, 'Pudge', -0.39), (4, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(1, 'Windranger', -0.9), (3, 'Grimstroke', -2.22), (4, 'Pudge', -3.76), (0, 'Clinkz', -0.04), (2, 'Zeus', -3.51)]
# [(1, 'Windranger', -0.9), (3, 'Grimstroke', -2.22), (4, 'Pudge', -3.76), (2, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(1, 'Windranger', -0.9), (4, 'Grimstroke', -0.12), (0, 'Pudge', -3.05), (2, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(1, 'Windranger', -0.9), (4, 'Grimstroke', -0.12), (0, 'Pudge', -3.05), (3, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(1, 'Windranger', -0.9), (4, 'Grimstroke', -0.12), (2, 'Pudge', -0.39), (0, 'Clinkz', -0.04), (3, 'Zeus', -0.88)]
# [(1, 'Windranger', -0.9), (4, 'Grimstroke', -0.12), (2, 'Pudge', -0.39), (3, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(1, 'Windranger', -0.9), (4, 'Grimstroke', -0.12), (3, 'Pudge', -2.38), (0, 'Clinkz', -0.04), (2, 'Zeus', -3.51)]
# [(1, 'Windranger', -0.9), (4, 'Grimstroke', -0.12), (3, 'Pudge', -2.38), (2, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(2, 'Windranger', -0.96), (0, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (3, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(2, 'Windranger', -0.96), (0, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (4, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(2, 'Windranger', -0.96), (0, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (1, 'Clinkz', -3.36), (4, 'Zeus', -2.44)]
# [(2, 'Windranger', -0.96), (0, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (4, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(2, 'Windranger', -0.96), (0, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (1, 'Clinkz', -3.36), (3, 'Zeus', -0.88)]
# [(2, 'Windranger', -0.96), (0, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (3, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(2, 'Windranger', -0.96), (1, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (3, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(2, 'Windranger', -0.96), (1, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (4, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(2, 'Windranger', -0.96), (1, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (0, 'Clinkz', -0.04), (4, 'Zeus', -2.44)]
# [(2, 'Windranger', -0.96), (1, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (4, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(2, 'Windranger', -0.96), (1, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (0, 'Clinkz', -0.04), (3, 'Zeus', -0.88)]
# [(2, 'Windranger', -0.96), (1, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (3, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(2, 'Windranger', -0.96), (3, 'Grimstroke', -2.22), (0, 'Pudge', -3.05), (1, 'Clinkz', -3.36), (4, 'Zeus', -2.44)]
# [(2, 'Windranger', -0.96), (3, 'Grimstroke', -2.22), (0, 'Pudge', -3.05), (4, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(2, 'Windranger', -0.96), (3, 'Grimstroke', -2.22), (1, 'Pudge', -1.83), (0, 'Clinkz', -0.04), (4, 'Zeus', -2.44)]
# [(2, 'Windranger', -0.96), (3, 'Grimstroke', -2.22), (1, 'Pudge', -1.83), (4, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(2, 'Windranger', -0.96), (3, 'Grimstroke', -2.22), (4, 'Pudge', -3.76), (0, 'Clinkz', -0.04), (1, 'Zeus', -0.76)]
# [(2, 'Windranger', -0.96), (3, 'Grimstroke', -2.22), (4, 'Pudge', -3.76), (1, 'Clinkz', -3.36), (0, 'Zeus', -1000.0)]
# [(2, 'Windranger', -0.96), (4, 'Grimstroke', -0.12), (0, 'Pudge', -3.05), (1, 'Clinkz', -3.36), (3, 'Zeus', -0.88)]
# [(2, 'Windranger', -0.96), (4, 'Grimstroke', -0.12), (0, 'Pudge', -3.05), (3, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(2, 'Windranger', -0.96), (4, 'Grimstroke', -0.12), (1, 'Pudge', -1.83), (0, 'Clinkz', -0.04), (3, 'Zeus', -0.88)]
# [(2, 'Windranger', -0.96), (4, 'Grimstroke', -0.12), (1, 'Pudge', -1.83), (3, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(2, 'Windranger', -0.96), (4, 'Grimstroke', -0.12), (3, 'Pudge', -2.38), (0, 'Clinkz', -0.04), (1, 'Zeus', -0.76)]
# [(2, 'Windranger', -0.96), (4, 'Grimstroke', -0.12), (3, 'Pudge', -2.38), (1, 'Clinkz', -3.36), (0, 'Zeus', -1000.0)]
# [(3, 'Windranger', -1.97), (0, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (2, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(3, 'Windranger', -1.97), (0, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (4, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(3, 'Windranger', -1.97), (0, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (1, 'Clinkz', -3.36), (4, 'Zeus', -2.44)]
# [(3, 'Windranger', -1.97), (0, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (4, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(3, 'Windranger', -1.97), (0, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (1, 'Clinkz', -3.36), (2, 'Zeus', -3.51)]
# [(3, 'Windranger', -1.97), (0, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (2, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(3, 'Windranger', -1.97), (1, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (2, 'Clinkz', -1000.0), (4, 'Zeus', -2.44)]
# [(3, 'Windranger', -1.97), (1, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (4, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(3, 'Windranger', -1.97), (1, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (0, 'Clinkz', -0.04), (4, 'Zeus', -2.44)]
# [(3, 'Windranger', -1.97), (1, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (4, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(3, 'Windranger', -1.97), (1, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (0, 'Clinkz', -0.04), (2, 'Zeus', -3.51)]
# [(3, 'Windranger', -1.97), (1, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (2, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(3, 'Windranger', -1.97), (2, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (1, 'Clinkz', -3.36), (4, 'Zeus', -2.44)]
# [(3, 'Windranger', -1.97), (2, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (4, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(3, 'Windranger', -1.97), (2, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (0, 'Clinkz', -0.04), (4, 'Zeus', -2.44)]
# [(3, 'Windranger', -1.97), (2, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (4, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(3, 'Windranger', -1.97), (2, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (0, 'Clinkz', -0.04), (1, 'Zeus', -0.76)]
# [(3, 'Windranger', -1.97), (2, 'Grimstroke', -1000.0), (4, 'Pudge', -3.76), (1, 'Clinkz', -3.36), (0, 'Zeus', -1000.0)]
# [(3, 'Windranger', -1.97), (4, 'Grimstroke', -0.12), (0, 'Pudge', -3.05), (1, 'Clinkz', -3.36), (2, 'Zeus', -3.51)]
# [(3, 'Windranger', -1.97), (4, 'Grimstroke', -0.12), (0, 'Pudge', -3.05), (2, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(3, 'Windranger', -1.97), (4, 'Grimstroke', -0.12), (1, 'Pudge', -1.83), (0, 'Clinkz', -0.04), (2, 'Zeus', -3.51)]
# [(3, 'Windranger', -1.97), (4, 'Grimstroke', -0.12), (1, 'Pudge', -1.83), (2, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(3, 'Windranger', -1.97), (4, 'Grimstroke', -0.12), (2, 'Pudge', -0.39), (0, 'Clinkz', -0.04), (1, 'Zeus', -0.76)]
# [(3, 'Windranger', -1.97), (4, 'Grimstroke', -0.12), (2, 'Pudge', -0.39), (1, 'Clinkz', -3.36), (0, 'Zeus', -1000.0)]
# [(4, 'Windranger', -3.38), (0, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (2, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(4, 'Windranger', -3.38), (0, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (3, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(4, 'Windranger', -3.38), (0, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (1, 'Clinkz', -3.36), (3, 'Zeus', -0.88)]
# [(4, 'Windranger', -3.38), (0, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (3, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(4, 'Windranger', -3.38), (0, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (1, 'Clinkz', -3.36), (2, 'Zeus', -3.51)]
# [(4, 'Windranger', -3.38), (0, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (2, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(4, 'Windranger', -3.38), (1, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (2, 'Clinkz', -1000.0), (3, 'Zeus', -0.88)]
# [(4, 'Windranger', -3.38), (1, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (3, 'Clinkz', -1000.0), (2, 'Zeus', -3.51)]
# [(4, 'Windranger', -3.38), (1, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (0, 'Clinkz', -0.04), (3, 'Zeus', -0.88)]
# [(4, 'Windranger', -3.38), (1, 'Grimstroke', -1000.0), (2, 'Pudge', -0.39), (3, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(4, 'Windranger', -3.38), (1, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (0, 'Clinkz', -0.04), (2, 'Zeus', -3.51)]
# [(4, 'Windranger', -3.38), (1, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (2, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(4, 'Windranger', -3.38), (2, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (1, 'Clinkz', -3.36), (3, 'Zeus', -0.88)]
# [(4, 'Windranger', -3.38), (2, 'Grimstroke', -1000.0), (0, 'Pudge', -3.05), (3, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(4, 'Windranger', -3.38), (2, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (0, 'Clinkz', -0.04), (3, 'Zeus', -0.88)]
# [(4, 'Windranger', -3.38), (2, 'Grimstroke', -1000.0), (1, 'Pudge', -1.83), (3, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(4, 'Windranger', -3.38), (2, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (0, 'Clinkz', -0.04), (1, 'Zeus', -0.76)]
# [(4, 'Windranger', -3.38), (2, 'Grimstroke', -1000.0), (3, 'Pudge', -2.38), (1, 'Clinkz', -3.36), (0, 'Zeus', -1000.0)]
# [(4, 'Windranger', -3.38), (3, 'Grimstroke', -2.22), (0, 'Pudge', -3.05), (1, 'Clinkz', -3.36), (2, 'Zeus', -3.51)]
# [(4, 'Windranger', -3.38), (3, 'Grimstroke', -2.22), (0, 'Pudge', -3.05), (2, 'Clinkz', -1000.0), (1, 'Zeus', -0.76)]
# [(4, 'Windranger', -3.38), (3, 'Grimstroke', -2.22), (1, 'Pudge', -1.83), (0, 'Clinkz', -0.04), (2, 'Zeus', -3.51)]
# [(4, 'Windranger', -3.38), (3, 'Grimstroke', -2.22), (1, 'Pudge', -1.83), (2, 'Clinkz', -1000.0), (0, 'Zeus', -1000.0)]
# [(4, 'Windranger', -3.38), (3, 'Grimstroke', -2.22), (2, 'Pudge', -0.39), (0, 'Clinkz', -0.04), (1, 'Zeus', -0.76)]
# [(4, 'Windranger', -3.38), (3, 'Grimstroke', -2.22), (2, 'Pudge', -0.39), (1, 'Clinkz', -3.36), (0, 'Zeus', -1000.0)]
# [(0, 'Sniper', -1.09), (1, 'Earthshaker', -7.56), (2, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(0, 'Sniper', -1.09), (1, 'Earthshaker', -7.56), (2, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(0, 'Sniper', -1.09), (1, 'Earthshaker', -7.56), (3, 'Keeper of the Light', -1.46), (2, 'Underlord', -0.01), (4, 'Void Spirit', -1000.0)]
# [(0, 'Sniper', -1.09), (1, 'Earthshaker', -7.56), (3, 'Keeper of the Light', -1.46), (4, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(0, 'Sniper', -1.09), (1, 'Earthshaker', -7.56), (4, 'Keeper of the Light', -0.27), (2, 'Underlord', -0.01), (3, 'Void Spirit', -6.85)]
# [(0, 'Sniper', -1.09), (1, 'Earthshaker', -7.56), (4, 'Keeper of the Light', -0.27), (3, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(0, 'Sniper', -1.09), (2, 'Earthshaker', -2.66), (1, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(0, 'Sniper', -1.09), (2, 'Earthshaker', -2.66), (1, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(0, 'Sniper', -1.09), (2, 'Earthshaker', -2.66), (3, 'Keeper of the Light', -1.46), (1, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(0, 'Sniper', -1.09), (2, 'Earthshaker', -2.66), (3, 'Keeper of the Light', -1.46), (4, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(0, 'Sniper', -1.09), (2, 'Earthshaker', -2.66), (4, 'Keeper of the Light', -0.27), (1, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(0, 'Sniper', -1.09), (2, 'Earthshaker', -2.66), (4, 'Keeper of the Light', -0.27), (3, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(0, 'Sniper', -1.09), (3, 'Earthshaker', -0.1), (1, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (4, 'Void Spirit', -1000.0)]
# [(0, 'Sniper', -1.09), (3, 'Earthshaker', -0.1), (1, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(0, 'Sniper', -1.09), (3, 'Earthshaker', -0.1), (2, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(0, 'Sniper', -1.09), (3, 'Earthshaker', -0.1), (2, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(0, 'Sniper', -1.09), (3, 'Earthshaker', -0.1), (4, 'Keeper of the Light', -0.27), (1, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(0, 'Sniper', -1.09), (3, 'Earthshaker', -0.1), (4, 'Keeper of the Light', -0.27), (2, 'Underlord', -0.01), (1, 'Void Spirit', -0.01)]
# [(0, 'Sniper', -1.09), (4, 'Earthshaker', -3.79), (1, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (3, 'Void Spirit', -6.85)]
# [(0, 'Sniper', -1.09), (4, 'Earthshaker', -3.79), (1, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(0, 'Sniper', -1.09), (4, 'Earthshaker', -3.79), (2, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(0, 'Sniper', -1.09), (4, 'Earthshaker', -3.79), (2, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(0, 'Sniper', -1.09), (4, 'Earthshaker', -3.79), (3, 'Keeper of the Light', -1.46), (1, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(0, 'Sniper', -1.09), (4, 'Earthshaker', -3.79), (3, 'Keeper of the Light', -1.46), (2, 'Underlord', -0.01), (1, 'Void Spirit', -0.01)]
# [(1, 'Sniper', -0.47), (0, 'Earthshaker', -1000.0), (2, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(1, 'Sniper', -0.47), (0, 'Earthshaker', -1000.0), (2, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(1, 'Sniper', -0.47), (0, 'Earthshaker', -1000.0), (3, 'Keeper of the Light', -1.46), (2, 'Underlord', -0.01), (4, 'Void Spirit', -1000.0)]
# [(1, 'Sniper', -0.47), (0, 'Earthshaker', -1000.0), (3, 'Keeper of the Light', -1.46), (4, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(1, 'Sniper', -0.47), (0, 'Earthshaker', -1000.0), (4, 'Keeper of the Light', -0.27), (2, 'Underlord', -0.01), (3, 'Void Spirit', -6.85)]
# [(1, 'Sniper', -0.47), (0, 'Earthshaker', -1000.0), (4, 'Keeper of the Light', -0.27), (3, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(1, 'Sniper', -0.47), (2, 'Earthshaker', -2.66), (0, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(1, 'Sniper', -0.47), (2, 'Earthshaker', -2.66), (0, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(1, 'Sniper', -0.47), (2, 'Earthshaker', -2.66), (3, 'Keeper of the Light', -1.46), (0, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(1, 'Sniper', -0.47), (2, 'Earthshaker', -2.66), (3, 'Keeper of the Light', -1.46), (4, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(1, 'Sniper', -0.47), (2, 'Earthshaker', -2.66), (4, 'Keeper of the Light', -0.27), (0, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(1, 'Sniper', -0.47), (2, 'Earthshaker', -2.66), (4, 'Keeper of the Light', -0.27), (3, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(1, 'Sniper', -0.47), (3, 'Earthshaker', -0.1), (0, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (4, 'Void Spirit', -1000.0)]
# [(1, 'Sniper', -0.47), (3, 'Earthshaker', -0.1), (0, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(1, 'Sniper', -0.47), (3, 'Earthshaker', -0.1), (2, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(1, 'Sniper', -0.47), (3, 'Earthshaker', -0.1), (2, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(1, 'Sniper', -0.47), (3, 'Earthshaker', -0.1), (4, 'Keeper of the Light', -0.27), (0, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(1, 'Sniper', -0.47), (3, 'Earthshaker', -0.1), (4, 'Keeper of the Light', -0.27), (2, 'Underlord', -0.01), (0, 'Void Spirit', -1000.0)]
# [(1, 'Sniper', -0.47), (4, 'Earthshaker', -3.79), (0, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (3, 'Void Spirit', -6.85)]
# [(1, 'Sniper', -0.47), (4, 'Earthshaker', -3.79), (0, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(1, 'Sniper', -0.47), (4, 'Earthshaker', -3.79), (2, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(1, 'Sniper', -0.47), (4, 'Earthshaker', -3.79), (2, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(1, 'Sniper', -0.47), (4, 'Earthshaker', -3.79), (3, 'Keeper of the Light', -1.46), (0, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(1, 'Sniper', -0.47), (4, 'Earthshaker', -3.79), (3, 'Keeper of the Light', -1.46), (2, 'Underlord', -0.01), (0, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (0, 'Earthshaker', -1000.0), (1, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (0, 'Earthshaker', -1000.0), (1, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(2, 'Sniper', -3.26), (0, 'Earthshaker', -1000.0), (3, 'Keeper of the Light', -1.46), (1, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (0, 'Earthshaker', -1000.0), (3, 'Keeper of the Light', -1.46), (4, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(2, 'Sniper', -3.26), (0, 'Earthshaker', -1000.0), (4, 'Keeper of the Light', -0.27), (1, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(2, 'Sniper', -3.26), (0, 'Earthshaker', -1000.0), (4, 'Keeper of the Light', -0.27), (3, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(2, 'Sniper', -3.26), (1, 'Earthshaker', -7.56), (0, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (1, 'Earthshaker', -7.56), (0, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(2, 'Sniper', -3.26), (1, 'Earthshaker', -7.56), (3, 'Keeper of the Light', -1.46), (0, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (1, 'Earthshaker', -7.56), (3, 'Keeper of the Light', -1.46), (4, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (1, 'Earthshaker', -7.56), (4, 'Keeper of the Light', -0.27), (0, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(2, 'Sniper', -3.26), (1, 'Earthshaker', -7.56), (4, 'Keeper of the Light', -0.27), (3, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (3, 'Earthshaker', -0.1), (0, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (3, 'Earthshaker', -0.1), (0, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(2, 'Sniper', -3.26), (3, 'Earthshaker', -0.1), (1, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (3, 'Earthshaker', -0.1), (1, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (3, 'Earthshaker', -0.1), (4, 'Keeper of the Light', -0.27), (0, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(2, 'Sniper', -3.26), (3, 'Earthshaker', -0.1), (4, 'Keeper of the Light', -0.27), (1, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (4, 'Earthshaker', -3.79), (0, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(2, 'Sniper', -3.26), (4, 'Earthshaker', -3.79), (0, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(2, 'Sniper', -3.26), (4, 'Earthshaker', -3.79), (1, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(2, 'Sniper', -3.26), (4, 'Earthshaker', -3.79), (1, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(2, 'Sniper', -3.26), (4, 'Earthshaker', -3.79), (3, 'Keeper of the Light', -1.46), (0, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(2, 'Sniper', -3.26), (4, 'Earthshaker', -3.79), (3, 'Keeper of the Light', -1.46), (1, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (0, 'Earthshaker', -1000.0), (1, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (4, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (0, 'Earthshaker', -1000.0), (1, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(3, 'Sniper', -7.54), (0, 'Earthshaker', -1000.0), (2, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (0, 'Earthshaker', -1000.0), (2, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(3, 'Sniper', -7.54), (0, 'Earthshaker', -1000.0), (4, 'Keeper of the Light', -0.27), (1, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(3, 'Sniper', -7.54), (0, 'Earthshaker', -1000.0), (4, 'Keeper of the Light', -0.27), (2, 'Underlord', -0.01), (1, 'Void Spirit', -0.01)]
# [(3, 'Sniper', -7.54), (1, 'Earthshaker', -7.56), (0, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (4, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (1, 'Earthshaker', -7.56), (0, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(3, 'Sniper', -7.54), (1, 'Earthshaker', -7.56), (2, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (1, 'Earthshaker', -7.56), (2, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (1, 'Earthshaker', -7.56), (4, 'Keeper of the Light', -0.27), (0, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(3, 'Sniper', -7.54), (1, 'Earthshaker', -7.56), (4, 'Keeper of the Light', -0.27), (2, 'Underlord', -0.01), (0, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (2, 'Earthshaker', -2.66), (0, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (2, 'Earthshaker', -2.66), (0, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(3, 'Sniper', -7.54), (2, 'Earthshaker', -2.66), (1, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (4, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (2, 'Earthshaker', -2.66), (1, 'Keeper of the Light', -1000.0), (4, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (2, 'Earthshaker', -2.66), (4, 'Keeper of the Light', -0.27), (0, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(3, 'Sniper', -7.54), (2, 'Earthshaker', -2.66), (4, 'Keeper of the Light', -0.27), (1, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (4, 'Earthshaker', -3.79), (0, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(3, 'Sniper', -7.54), (4, 'Earthshaker', -3.79), (0, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (1, 'Void Spirit', -0.01)]
# [(3, 'Sniper', -7.54), (4, 'Earthshaker', -3.79), (1, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(3, 'Sniper', -7.54), (4, 'Earthshaker', -3.79), (1, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (0, 'Void Spirit', -1000.0)]
# [(3, 'Sniper', -7.54), (4, 'Earthshaker', -3.79), (2, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(3, 'Sniper', -7.54), (4, 'Earthshaker', -3.79), (2, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(4, 'Sniper', -6.99), (0, 'Earthshaker', -1000.0), (1, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (3, 'Void Spirit', -6.85)]
# [(4, 'Sniper', -6.99), (0, 'Earthshaker', -1000.0), (1, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(4, 'Sniper', -6.99), (0, 'Earthshaker', -1000.0), (2, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(4, 'Sniper', -6.99), (0, 'Earthshaker', -1000.0), (2, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(4, 'Sniper', -6.99), (0, 'Earthshaker', -1000.0), (3, 'Keeper of the Light', -1.46), (1, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(4, 'Sniper', -6.99), (0, 'Earthshaker', -1000.0), (3, 'Keeper of the Light', -1.46), (2, 'Underlord', -0.01), (1, 'Void Spirit', -0.01)]
# [(4, 'Sniper', -6.99), (1, 'Earthshaker', -7.56), (0, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (3, 'Void Spirit', -6.85)]
# [(4, 'Sniper', -6.99), (1, 'Earthshaker', -7.56), (0, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(4, 'Sniper', -6.99), (1, 'Earthshaker', -7.56), (2, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(4, 'Sniper', -6.99), (1, 'Earthshaker', -7.56), (2, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(4, 'Sniper', -6.99), (1, 'Earthshaker', -7.56), (3, 'Keeper of the Light', -1.46), (0, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(4, 'Sniper', -6.99), (1, 'Earthshaker', -7.56), (3, 'Keeper of the Light', -1.46), (2, 'Underlord', -0.01), (0, 'Void Spirit', -1000.0)]
# [(4, 'Sniper', -6.99), (2, 'Earthshaker', -2.66), (0, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(4, 'Sniper', -6.99), (2, 'Earthshaker', -2.66), (0, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(4, 'Sniper', -6.99), (2, 'Earthshaker', -2.66), (1, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (3, 'Void Spirit', -6.85)]
# [(4, 'Sniper', -6.99), (2, 'Earthshaker', -2.66), (1, 'Keeper of the Light', -1000.0), (3, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(4, 'Sniper', -6.99), (2, 'Earthshaker', -2.66), (3, 'Keeper of the Light', -1.46), (0, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(4, 'Sniper', -6.99), (2, 'Earthshaker', -2.66), (3, 'Keeper of the Light', -1.46), (1, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(4, 'Sniper', -6.99), (3, 'Earthshaker', -0.1), (0, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(4, 'Sniper', -6.99), (3, 'Earthshaker', -0.1), (0, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (1, 'Void Spirit', -0.01)]
# [(4, 'Sniper', -6.99), (3, 'Earthshaker', -0.1), (1, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (2, 'Void Spirit', -4.61)]
# [(4, 'Sniper', -6.99), (3, 'Earthshaker', -0.1), (1, 'Keeper of the Light', -1000.0), (2, 'Underlord', -0.01), (0, 'Void Spirit', -1000.0)]
# [(4, 'Sniper', -6.99), (3, 'Earthshaker', -0.1), (2, 'Keeper of the Light', -1000.0), (0, 'Underlord', -1000.0), (1, 'Void Spirit', -0.01)]
# [(4, 'Sniper', -6.99), (3, 'Earthshaker', -0.1), (2, 'Keeper of the Light', -1000.0), (1, 'Underlord', -1000.0), (0, 'Void Spirit', -1000.0)]
# [(0, 'Sniper', -1.09), (1, 'Void Spirit', -0.01), (2, 'Underlord', -0.01), (3, 'Earthshaker', -0.1), (4, 'Keeper of the Light', -0.27)]
